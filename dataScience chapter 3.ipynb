# %%
nums = (3, 4, 6)

num1, num2, num3 = nums

even_nums = (2, num2, num3)
print(even_nums)
# Out:
# (2, 4, 6)

# %%
import pandas as pd

df = pd.read_csv('/home/jose/Downloads/DataCamp/03-python-data-science-toolbox-(part-1)/_datasets/tweets.csv')
df
langs_count = {}

col = df['lang']

for entry in col:
    print(langs_count.keys())
    if entry in langs_count.keys():
        langs_count[entry] += 1
    else:
        langs_count[entry] = 1
print(langs_count)
# Out:
# dict_keys([])
# dict_keys(['en'])
# dict_keys(['en'])
# dict_keys(['en', 'et'])
# dict_keys(['en', 'et'])
# dict_keys(['en', 'et'])
# dict_keys(['en', 'et'])
# dict_keys(['en', 'et'])
# dict_keys(['en', 'et'])
# dict_keys(['en', 'et'])
# dict_keys(['en', 'et'])
# dict_keys(['en', 'et'])
# dict_keys(['en', 'et'])
# dict_keys(['en', 'et'])
# dict_keys(['en', 'et'])
# dict_keys(['en', 'et'])
# dict_keys(['en', 'et'])
# dict_keys(['en', 'et'])
# dict_keys(['en', 'et'])
# dict_keys(['en', 'et'])
# dict_keys(['en', 'et'])
# dict_keys(['en', 'et', 'und'])
# dict_keys(['en', 'et', 'und'])
# dict_keys(['en', 'et', 'und'])
# dict_keys(['en', 'et', 'und'])
# dict_keys(['en', 'et', 'und'])
# dict_keys(['en', 'et', 'und'])
# dict_keys(['en', 'et', 'und'])
# dict_keys(['en', 'et', 'und'])
# dict_keys(['en', 'et', 'und'])
# dict_keys(['en', 'et', 'und'])
# dict_keys(['en', 'et', 'und'])
# dict_keys(['en', 'et', 'und'])
# dict_keys(['en', 'et', 'und'])
# dict_keys(['en', 'et', 'und'])
# ...

# %%
import pandas as pd

tweetsDf = pd.read_csv('/home/jose/Downloads/DataCamp/03-python-data-science-toolbox-(part-1)/_datasets/tweets.csv')

def countEntries(df, colName):
    
    largs_count = {}
    
    col = df[colName]
    print(col)
    
    for entry in col:
        
        # If the language is in langs_count, add 1
        if entry in langs_count.keys():
            langs_count[entry] += 1
        # Else add the language to langs_count, set the value to 1
        else:
            langs_count[entry] = 1
    return langs_count

result = countEntries(tweetsDf, 'lang')
print(result)
# Out:
# 0      en
# 1      en
# 2      et
# 3      en
# 4      en
# 5      en
# 6      en
# 7      en
# 8      en
# 9      en
# 10     en
# 11     en
# 12     en
# 13     en
# 14     en
# 15     en
# 16     en
# 17     en
# 18     en
# 19     en
# 20    und
# 21     en
# 22     en
# 23     en
# 24     en
# 25     en
# 26     en
# 27     en
# 28     en
# 29    und
#      ...
# 70     en
# 71     en
# 72     en
# 73     en
# 74     en
# 75     en
# 76     en
# 77     en
# 78     en
# 79     en
# 80     en
# 81     en
# 82     en
# 83     en
# 84     en
# 85     en
# 86     en
# 87     en
# 88     en
# 89     en
# 90     en
# 91     en
# 92     en
# 93     en
# 94     en
# 95     en
# 96     en
# 97     en
# 98     en
# 99     en
# Name: lang, Length: 100, dtype: object
# {'en': 194, 'et': 2, 'und': 4}

# %%
s = {'uno': 6, 'dos': 2}
s['uno']
s['tres'] = 3
s.keys()
s
# Out:
# {'uno': 6, 'dos': 2, 'tres': 3}

# %%
x = str(5)
print(x)
print(type(x))
# Out:
# 5
# <class 'str'>

# %%
def square():
    new_value = 4 ** 2
    print(new_value)
    pass
square()
# Out:
# 16

# %%
def square(value):
    new_value = value ** 2
    print(new_value)

square(6)
square(3)
# Out:
# 36
# 9

# %%
def square(value):
    new_value = value ** 2
    """ Return the square the value """
    return new_value

print(square(6))
print(square(3))
# Out:
# 36
# 9

# %%
def raise_of_power(value1, value2):
    """Raise value1 on the power of value2"""
    new_value = value1 ** value2
    return new_value

result = raise_of_power(2, 3)
print(result)
# Out:
# 8

# %%
even_nums = (2, 4, 6)
print(even_nums)
# Out:
# (2, 4, 6)

# %%
a, b, c = even_nums
print(a)
print(b)
print(c)
print(even_nums[2])
# Out:
# 2
# 4
# 6
# 6

# %%
def raise_both(value1, value2):
    """ Raise value1 to the power of value2 and vice versa"""
    
    new_value1 = value1 ** value2
    new_value2 = value2 ** value1
    
    new_tuple = (new_value1, new_value2)
    
    return new_tuple

result = raise_both(2, 3)
print(result)
# Out:
# (8, 9)

# %%
def shout_all(word1, word2):
    shout1 = word1 + '!!!'
    shout2 = word2 + '!!!'
    shout_words = (shout1 ,shout2)

    return shout_words

yell1, yell2 = shout_all('congratulations', 'you')

print(yell1)
print(yell2)
# Out:
# congratulations!!!
# you!!!

# %%
def shout(word):
    """ Return a string with three exclamations marks """
    shout_word = word + '!!!'

    return shout_word
    pass

# pass 'congratulations' to shout: yell

yell = shout('congratulations')

print(yell)
# Out:
# congratulations!!!

# %%
def shout_all(word1, word2):
    shout1 = word1 + '!!!'
    shout2 = word2 + '!!!'
    shout_words = shout1 + shout2

    return shout_words

yell1 = shout_all('congratulations', 'you')

print(yell1)
# Out:
# congratulations!!!you!!!

# %%
x = 4.0
y1 = str(x)
y2 = print(x)
type(y1)
# Out:
# 4.0
# str

# %%
def shout(word):
    """ Print a string with exclamation marks"""
    shout_word = word + '!!!'
    
    print(shout_word)

shout('congratulations')
# Out:
# congratulations!!!

# %%
object1 = "data" + "analysis" + "visualization"
object2 = 1 * 3
object3 = "1" * 3

print(object1)
print(object2)
print(object3)
# Out:
# dataanalysisvisualization
# 3
# 111

# %%
def shout():
    """Print a string with three exclamation marks"""
    # Concatenate the strings: shout_word
    shout_word = 'congratulations' + '!!!'

    # Print shout_word
    print(shout_word)

# Call shout
shout()
# Out:
# congratulations!!!

# %%
import pandas as pd

dataTweeter = pd.read_csv('/home/jose/Downloads/DataCamp/03-python-data-science-toolbox-(part-1)/_datasets/tweets.csv')

dataTweeter
# Out:
#     contributors  coordinates                      created_at  \
# 0            NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 1            NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 2            NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 3            NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 4            NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 5            NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 6            NaN          NaN  Tue Mar 29 23:40:18 +0000 2016
# 7            NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 8            NaN          NaN  Tue Mar 29 23:40:18 +0000 2016
# 9            NaN          NaN  Tue Mar 29 23:40:18 +0000 2016
# 10           NaN          NaN  Tue Mar 29 23:40:18 +0000 2016
# 11           NaN          NaN  Tue Mar 29 23:40:17 +0000 2016
# 12           NaN          NaN  Tue Mar 29 23:40:18 +0000 2016
# 13           NaN          NaN  Tue Mar 29 23:40:18 +0000 2016
# ...

# %%
import pandas as pd

datosEstadoAgua = pd.read_csv('Downloads/Caracter_sticas_Calidad_del_Agua_-_SIVICAP.csv')
datosEstadoAgua
# Out:
#        AÑO     DEPARTAMENTO             MUNICIPO  TOTAL MUESTRAS  \
# 0     2015        Antioquia            Abejorral              44
# 1     2015        Antioquia             Abriaquí              24
# 2     2015        Antioquia           Alejandría              28
# 3     2015        Antioquia                Amagá              26
# 4     2015        Antioquia               Amalfi              58
# 5     2015        Antioquia                Andes              26
# 6     2015        Antioquia          Angelópolis              26
# 7     2015        Antioquia            Angostura              29
# 8     2015        Antioquia                Anorí              25
# 9     2015        Antioquia                 Anza              22
# 10    2015        Antioquia             Apartadó             138
# 11    2015        Antioquia            Arboletes              26
# 12    2015        Antioquia              Argelia             154
# ...

# %%
# Import pandas
import pandas as pd

# Import Twitter data as DataFrame: df
tweets_df = pd.read_csv('/home/jose/Downloads/DataCamp/03-python-data-science-toolbox-(part-1)/_datasets/tweets.csv')

# Define count_entries()
def count_entries(df, col_name='lang'):
    """Return a dictionary with counts of
    occurrences as value for each key."""

    # Initialize an empty dictionary: cols_count
    cols_count = {}
    
    # Extract column from DataFrame: col
    col = df[col_name]
    print(col)

    # Iterate over the column in DataFrame
    for entry in col:

        # If entry is in cols_count, add 1
        if entry in cols_count.keys():
            cols_count[entry] += 1

        # Else add the entry to cols_count, set the value to 1
        else:
            cols_count[entry] = 1

    # Return the cols_count dictionary
    return cols_count

# Call count_entries(): result1
result1 = count_entries(tweets_df, col_name='lang')

# Call count_entries(): result2
result2 = count_entries(tweets_df, col_name='source')

# Print result1 and result2
print(result1)
print(result2)
# Out:
# 0      en
# 1      en
# 2      et
# 3      en
# 4      en
# 5      en
# 6      en
# 7      en
# 8      en
# 9      en
# 10     en
# 11     en
# 12     en
# 13     en
# 14     en
# 15     en
# 16     en
# 17     en
# 18     en
# 19     en
# 20    und
# 21     en
# 22     en
# 23     en
# 24     en
# 25     en
# 26     en
# 27     en
# 28     en
# 29    und
#      ...
# 70     en
# 71     en
# 72     en
# 73     en
# 74     en
# 75     en
# 76     en
# 77     en
# 78     en
# 79     en
# 80     en
# 81     en
# 82     en
# 83     en
# 84     en
# 85     en
# 86     en
# 87     en
# 88     en
# 89     en
# 90     en
# 91     en
# 92     en
# 93     en
# 94     en
# 95     en
# 96     en
# 97     en
# 98     en
# 99     en
# Name: lang, Length: 100, dtype: object
# 0     <a href="http://twitter.com" rel="nofollow">Tw...
# 1     <a href="http://twitter.com" rel="nofollow">Tw...
# 2     <a href="http://www.facebook.com/twitter" rel=...
# ...

# %%
#global vs scope
def square(value):
    new_val = value ** 2
    return new_val

square(6)
# Out:
# 36

# %%
#global vs scope
new_val = 10

def square(value):
    new_val2 = new_val ** 2
    return new_val2

print(square(6))
print(new_val)
# Out:
# 100
# 10

# %%
#global vs scope
new_val = 10

def square(value):
    global new_val
    new_val = value ** 2
    return new_val

print(square(6))
print(new_val)
# Out:
# 36
# 36

# %%
#Nested function

def mod2plus(x1, x2, x3):
    def inner(x):
        return x%2 + 5
    return(inner(x1), inner(x2), inner(x3))

print(mod2plus(1, 2, 3))
# Out:
# (6, 5, 6)

# %%
#Nested function

def raise_val(n):
    def inner(x):
        return x ** n
    return(inner)

square = raise_val(2)
cube = raise_val(3)
print(square(2))
print(cube(3))
# Out:
# 4
# 27

# %%
def outer():
    n = 1
    def inner():
        nonlocal n
        n = 2
        print(n)
        
    inner()
    print(n)
outer()
# Out:
# 2
# 2

# %%
def add_all(*args):
    sum_all = 0
    for num in args:
        sum_all += num
        
    return sum_all

print(add_all(1))
print(add_all(1, 2))
print(add_all(5, 10, 15, 20))
# Out:
# 1
# 3
# 50

# %%
from math import cos, sin

num = 5*cos(4) - 4*sin(4)
numDerivate = -4*(1.358229874*cos(2*1.358229874) + 3*sin(2*1.358229874))
print(cos(0.01))
print(1.6666666666666666666 * (10 ** -6)+0.99995)
# Out:
# 0.9999500004166653
# 0.9999516666666667

# %%
def power(number, pow=1):
    new_value = number ** pow
    return new_value

power(9, 3)
power(9)
# Out:
# 9

# %%
def add_all(*args):
    sum_all = 0
    
    for num in args:
        sum_all += num
    
    return sum_all

add_all(1)
add_all(1, 2)
add_all(5, 10, 15, 20)
# Out:
# 50

# %%
def print_all(**kwargs):
    print(kwargs)
    for key, value in kwargs.items():
        print(key + ": " + value)
        
print_all(name="dumbledore", job="headmaster")
# Out:
# {'name': 'dumbledore', 'job': 'headmaster'}
# name: dumbledore
# job: headmaster

# %%
def gibberish(*args):

    hodgepodge = ""
    for word in args:
        hodgepodge += word
        pass
    pass

    return hodgepodge

one_word = gibberish('luke')

many_words = gibberish("luke", "leia", "han", "obi", "darth")

print(one_word)
print(many_words)
# Out:
# luke
# lukeleiahanobidarth

# %%
def report_status(**kwargs):

    print("\nBEGIN: REPORT\n")
    
    for key, value in kwargs.items():
        print(key + ": " + value)
        pass
    pass

    print("\nEND REPORT\n")

report_status(name='luke', affiliation='jedi', status='missing')
report_status(name='anakin', affiliation='sith lord', status='deceased')
# Out:
# BEGIN: REPORT
#
# name: luke
# affiliation: jedi
# status: missing
#
# END REPORT
#
#
# BEGIN: REPORT
#
# name: anakin
# affiliation: sith lord
# status: deceased
#
# END REPORT

# %%
def shout_echo(word1, echo=1):

    echo_word = word1 * echo
    
    shout_word = echo_word + '!!!'

    return shout_word

no_echo = shout_echo('Hey')
with_echo = shout_echo('Hey', 5)

print(no_echo)
print(with_echo)
# Out:
# Hey!!!
# HeyHeyHeyHeyHey!!!

# %%
def shout_echo(word1, echo=1, intense=False):

    echo_word = word1 * echo
    
    if intense is True:
        echo_word_new = echo_word.upper() + '!!!'
    else:
        echo_word_new = echo_word + '!!!'

    return echo_word_new
    
with_big_echo = shout_echo('Hey', 5, True)
big_no_echo = shout_echo('Hey', intense=True)
big_echo = shout_echo('Hey', 6)

print(with_big_echo)
print(big_no_echo)
print(big_echo)
# Out:
# HEYHEYHEYHEYHEY!!!
# HEY!!!
# HeyHeyHeyHeyHeyHey!!!

# %%
def three_shouts(word1, word2, word3):
    def inner(word):
        return word + '!!!'
    return (inner(word1), inner(word2), inner(word3))
print(three_shouts('a','b','c'))
# Out:
# ('a!!!', 'b!!!', 'c!!!')

# %%
def echo(n):

    def inner_echo(word1):
        echo_word = word1 * n
        return echo_word
    return inner_echo

twice = echo(2)
thrice = echo(3)

print(twice('hello'), thrice('hello'))
# Out:
# hellohello hellohellohello

# %%
def func1():
    num = 3
    print(num)
def func2():
    global num
    double_num = num * 2
    num = 6
    print(double_num)

func1()
func2()
# Out:
# 3
# 12

# %%
# Create a string: team
team = "teen titans"

# Define change_team()
def change_team():
    """Change the value of the global variable team."""

    # Use team in global scope
    global team

    # Change the value of team in global: team
    team = "justice league"

# Print team
print(team)

# Call change_team()
change_team()

# Print team
print(team)
# Out:
# teen titans
# justice league

# %%
def echo_shout(word):

    echo_word = word * 2
    print(echo_word)

    def shout():
        nonlocal echo_word
        echo_word = echo_word + '!!!'
    
    shout()        
    print(echo_word)

echo_shout('hello')
# Out:
# hellohello
# hellohello!!!

# %%
import pandas as pd

datosEstadoAgua = pd.read_csv('Downloads/Caracter_sticas_Calidad_del_Agua_-_SIVICAP.csv')

result = filter(lambda x: x[0:2] == 'Tu', datosEstadoAgua['MUNICIPO'])

res_list = list(result)

for department in res_list:
    print(department)
# Out:
# Turbo
# Tubará
# Turbaco
# Turbaná
# Tunja
# Tununguá
# Turmequé
# Tuta
# Tutazá
# Tuluá

# %%
datosEstadoAgua = pd.read_csv('Downloads/Caracter_sticas_Calidad_del_Agua_-_SIVICAP.csv')

def count_entries(df, col_name='NIVEL DE RIESGO PROMEDIO'):
    cols_count = {}

    try:
        col = datosEstadoAgua[col_name]
        for entry in col:
            if entry in cols_count.keys():
                cols_count[entry] += 1
            else:
                cols_count[entry] = 1
                pass
            pass
        return cols_count
        pass
    except:
        print('The DataFrame does not have a ' + col_name + ' column.')
        pass

result1 = count_entries(datosEstadoAgua, 'NIVEL DE RIESGO PROMEDIO')
print(result1)

result2 = count_entries(datosEstadoAgua, 'NIVEL DE RIESGO PROMEDIO')
# Out:
# {'SIN RIESGO': 281, 'INVIABLE SANITARIAMENTE': 17, 'MEDIO': 262, 'BAJO': 177, 'ALTO': 282}

# %%
def count_ocurrences(datosEstadoAgua, col_name='TOTAL MUESTRAS'):
    count_keys = {}
    
    try:
        colTotalMuestras = datosEstadoAgua[col_name]
        for data in colTotalMuestras:
            if data in count_keys.keys():
                count_keys[data] += 1
            else:
                count_keys[data] = 1
        return count_keys
    except:
        print('no data found')

count_ocurrences(datosEstadoAgua, col_name='TOTAL MUESTRAS')
# Out:
# {44: 7,
#  24: 28,
#  28: 23,
#  26: 33,
#  58: 7,
#  29: 20,
#  25: 22,
#  22: 19,
#  138: 1,
#  154: 1,
#  41: 5,
#  127: 2,
#  27: 23,
#  21: 19,
#  128: 3,
#  43: 4,
#  70: 2,
#  49: 10,
#  88: 2,
#  77: 3,
#  52: 9,
#  18: 13,
#  34: 13,
#  85: 3,
#  51: 7,
#  98: 2,
#  37: 8,
#  106: 1,
#  76: 5,
#  1229: 1,
#  48: 6,
#  50: 5,
#  12: 69,
#  31: 6,
#  47: 4,
#  23: 31,
#  74: 3,
#  90: 5,
#  7: 22,
#  35: 13,
#  30: 16,
#  13: 29,
#  69: 4,
#  114: 1,
#  9: 26,
#  320: 2,
#  94: 2,
#  82: 4,
#  87: 1,
#  3: 9,
#  101: 3,
#  78: 3,
#  261: 1,
#  42: 6,
#  67: 2,
#  120: 3,
#  102: 3,
#  40: 3,
#  32: 12,
#  95: 3,
#  33: 17,
#  161: 1,
#  173: 2,
#  2546: 1,
#  11: 37,
#  14: 20,
#  5: 10,
#  6: 14,
#  467: 1,
#  8: 26,
#  17: 10,
#  19: 14,
#  10: 28,
#  20: 16,
#  16: 20,
#  15: 14,
#  1: 7,
#  75: 2,
#  39: 9,
#  183: 1,
#  38: 4,
#  45: 2,
#  64: 9,
#  86: 1,
#  53: 4,
#  129: 1,
#  73: 2,
#  233: 2,
#  72: 6,
#  68: 1,
#  171: 1,
#  197: 2,
#  117: 1,
#  151: 2,
#  116: 1,
# ...

# %%
import pandas as pd

def count_entries(df, col_name='NIVEL DE RIESGO PROMEDIO'):
    
    if col_name not in df.columns:
        raise ValueError('The dataframe does not have a ' + col_name + ' column.')
    
    cols_count = {}

    col = df[col_name]
    
    for entry in col:
        if entry in cols_count.keys():
            cols_count[entry] += 1
            pass
        else:
            cols_count[entry] = 1
            pass
    return cols_count
    pass

result1 = count_entries(datosEstadoAgua, 'NIVEL DE RIESGO PROMEDIO')
print(result1)
# Out:
# {'SIN RIESGO': 281, 'INVIABLE SANITARIAMENTE': 17, 'MEDIO': 262, 'BAJO': 177, 'ALTO': 282}

# %%
raise_to_power = lambda x, y: x**y
raise_to_power(2, 3)
# Out:
# 8

# %%
nums = [48, 5, 9, 21, 1]
square_all = map(lambda num: num ** 2, nums)
print(square_all)
print(list(square_all))
# Out:
# ...
# [2304, 25, 81, 441, 1]

# %%
print(float(23))
print(float('23'))
print(float('hello'))
# Out:
# 23.0
# 23.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-115e5f852c33> in <module>
#       1 print(float(23))
#       2 print(float('23'))
# ----> 3 print(float('hello'))
#
# ValueError: could not convert string to float: 'hello'

# %%
def sqrt(x):
    return x ** 0.5

sqrt(4)
sqrt(10)
sqrt('hello')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-c121d188a1b1> in <module>
#       4 sqrt(4)
#       5 sqrt(10)
# ----> 6 sqrt('hello')
#
# <ipython-input-2-c121d188a1b1> in sqrt(x)
#       1 def sqrt(x):
# ----> 2     return x ** 0.5
#       3
#       4 sqrt(4)
#       5 sqrt(10)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'float'

# %%
def sqrt(x):
    if x < 0:
        raise ValueError('x must be non-negative')
    try:
        return x ** 0.5
    except TypeError:
        print('x must be an int or float')
        
print(sqrt(-4))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-09bf25dcc5f4> in <module>
#       7         print('x must be an int or float')
#       8
# ----> 9 print(sqrt(-4))
#
# <ipython-input-13-09bf25dcc5f4> in sqrt(x)
#       1 def sqrt(x):
#       2     if x < 0:
# ----> 3         raise ValueError('x must be non-negative')
#       4     try:
#       5         return x ** 0.5
#
# ValueError: x must be non-negative

# %%
def shout_echo(word1, echo =1):
    if echo < 0:
        raise ValueError('echo must be greater than 0');

    echo_word = word1 * echo

    shout_word = echo_word + '!!!'

    return shout_word

shout_echo("particle", echo=6)
# Out:
# 'particleparticleparticleparticleparticleparticle!!!'

# %%
def shout_echo(word1, echo =1):
    
    echo_word = ""
    shout_word = ""

    try:
        echo_word = word1 * echo
        shout_word = echo_word + '!!!'
        pass
    except:
        print('word1 must be a string and echo must be an integer')
        pass
    return shout_word

shout_echo("particle", echo="aceleration")
# Out:
# word1 must be a string and echo must be an integer
# ''

# %%
fellowship = ['frodo', 'samwise', 'merry', 'aragorn', 'legolas', 'boromir', 'gimli']
result = filter(lambda member: len(member) > 6, fellowship)
result = list(result)

for result in result:
    print(result)
# Out:
# samwise
# aragorn
# legolas
# boromir

# %%
spells = ['protego', 'accio', 'expecto patronum', 'legillimers']
result = map(lambda powers: powers + '!!!', spells)
result = list(result)

for result in result:
    print(result)
# Out:
# protego!!!
# accio!!!
# expecto patronum!!!
# legillimers!!!

# %%
len(('jaime', 'cersei', 'tywin', 'tyrion', 'joffrey'))
# Out:
# 5

# %%
from functools import reduce

stark = ['robb', 'sansa', 'arya', 'eddard', 'jon']
result = reduce(lambda item1, item2: item1 + item2, stark)
print(result)
# Out:
# robbsansaaryaeddardjon

# %%
# Define echo_word as a lambda function: echo_word
echo_word = lambda word1, echo: word1 * echo

# Call echo_word: result
result = echo_word('hey', 5)

# Print result
print(result)
# Out:
# heyheyheyheyhey

# %%
import tensorflow as tf
